# %%
from shapely.geometry import Point
import geopandas as gpd
import numpy as np
from src.data_gen.region_generator import RegionGenerator
from src.data.measurment import Measurement
from src.grouping.brute_force import Brute_Force
from src.controller.benchmark_runner import BenchmarkRunner

# %%
BenchmarkRunner(algo=Brute_Force(.5)).run(
    max_houses=8, 
    max_time_steps=100, 
    house_interval=1, 
    time_step_interval=20,
    file_location="C:/Users/steve/OneDrive/Dokumente/Universität/BA/Messung"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 BenchmarkRunner(algo=Brute_Force(.5)).run(
#       2     max_houses=8,
#       3     max_time_steps=100,
#       4     house_interval=1,
#
# File c:\Users\steve\energy_grouping\src\controller\benchmark_runner.py:40, in BenchmarkRunner.run(self, max_houses, max_time_steps, house_interval, time_step_interval, file_location)
#      34 	for time_step_index, time_step_count in enumerate(time_steps):
#      35 		region = self.generator.random(
#      36 			n_houses=house_count,
#      37 			time_steps=time_step_count,
#      38 			max_energy=self.max_energy,
#      39 		)
# ---> 40 		results[house_index, time_step_index] = Measurement(
#      41 			region, self.algo
#      42 		).get_duration()
#      44 file_location = Path(file_location)
#      45 file_location.mkdir(parents=True, exist_ok=True)
#
# File c:\Users\steve\energy_grouping\src\data\measurment.py:8, in Measurement.__init__(self, region, algo)
#       6 def __init__(self, region: Region, algo: GroupingAlgo):
#       7     self.algo = algo
# ----> 8     self.run(region)
#
# File c:\Users\steve\energy_grouping\src\data\measurment.py:14, in Measurement.run(self, region)
#      12 self.region = region
#      13 self.start = perf_counter()
# ---> 14 self.grouped_region = self.algo.group(self.region)
#      15 self.end = perf_counter()
#      16 return self.get_duration()
#
# File c:\Users\steve\energy_grouping\src\grouping\brute_force.py:69, in Brute_Force.group(self, region)
#      50 """
#      51 vector_dict: {id -> vector, ...}
#      52 vector: (dim1, dim2, ...)
#    (...)     55 return: {id -> lable, ...}
#      56 """
#      57 # 1. find all unique group combinations (power set).
#      58 # combinations = self._powerset(set(region.get_indexes()))
#      59
#    (...)     67
#      68 # 3. find all partitions of the region
# ---> 69 partitions = self._partitions(set(region.get_indexes()))
#      70 self._partitions = partitions
#      72 #4. calculate the autarky for each partition and find the best one
#
# TypeError: 'set' object is not callable
