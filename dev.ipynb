# %%
from time import perf_counter
start = perf_counter()
from shapely.geometry import Point
print(f'imported Point in {perf_counter() - start:.3f} sec')
start = perf_counter()
import geopandas as gpd
print(f'imported gpd in {perf_counter() - start:.3f} sec')
start = perf_counter()
import pandas as pd
print(f'imported pd in {perf_counter() - start:.3f} sec')
start = perf_counter()
import numpy as np
print(f'imported np in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data_gen.region_generator import RegionGenerator
print(f'imported RegionGen in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data.measurment import Measurement
print(f'imported Measurement in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.brute_force import Brute_Force
print(f'imported BruteF in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.controller.benchmark_runner import BenchmarkRunner
print(f'imported Benchmark in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.animation.animation import Animation
print(f'imported Animation in {perf_counter() - start:.3f} sec')
start = perf_counter()
import plotly.graph_objects as go
print(f'imported Go in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.animation.trajectory import Trajectory
print(f'imported traj in {perf_counter() - start:.3f} sec')
start = perf_counter()
import plotly.express as px
print(f'imported px in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.utilities.seed_container import Seed_Container
print(f'imported SeedContainer in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data.grouped_region import GroupedRegion
print(f'imported Grouped_Region in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.genetic import Genetic
print(f'imported Genetic in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.k_means import K_Means
print(f'imported K-Means in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.utilities.bbox_selector import BBoxSelector
print(f'imported selector in {perf_counter() - start:.3f} sec')
# Out:
# imported Point in 0.231 sec
# imported gpd in 0.785 sec
# imported pd in 0.000 sec
# imported np in 0.000 sec
# imported RegionGen in 0.268 sec
# imported Measurement in 0.022 sec
# imported BruteF in 0.013 sec
# imported Benchmark in 0.002 sec
# imported Animation in 0.004 sec
# imported Go in 0.000 sec
# imported traj in 0.000 sec
# imported px in 0.175 sec
# imported SeedContainer in 0.000 sec
# imported Grouped_Region in 0.000 sec
# imported Genetic in 0.001 sec
# imported K-Means in 1.562 sec
# imported selector in 0.145 sec

# %%
selector = BBoxSelector()
selector.display()
# Out:
# Map(center=[50.8, 10.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %%
bbox = (10.227592, 53.484326, 10.228944, 53.4849) #klein
bbox = selector.bbox
print(bbox)
# Out:
# (10.172709, 53.474974, 10.174544, 53.475536)

# %%
distance_weight = 1
sc = Seed_Container(seed=1452105090)
#region = RegionGenerator(seed_container=sc).random(40, 1, 10)
region = RegionGenerator(seed_container=sc).geo_random(bbox, 1, 10)
#algo = K_Means(sc, distance_weight, 3, 10)
algo = Genetic(sc, distance_weight, 3, 40)
#algo = Brute_Force(distance_weight, 3)
animation = Animation()
for frame in algo.group(region=region, animate=True):
    animation.receive(frame)

# %%
animation.play(speed = 50)
result = algo.result
sc.seed()
# Out:
# 1452105090

# %%
animation.play(speed = 50)
result = algo.result
sc.seed()
# Out:
# 1452105090

# %% [markdown]
# warum nur alle 3 schritte änderung? warum bei distance weight 1 nicht gruppen bildung,

# %%
print(f'before: {result.get_autarky_without_groups():.3f}, after: {result.region_autarky():.3f}')

result.houses
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f'before: {result.get_autarky_without_groups():.3f}, after: {result.region_autarky():.3f}')
#       2
#       3 result.houses
#
# AttributeError: 'function' object has no attribute 'get_autarky_without_groups'

# %%
print(f'seed: {sc.seed()}')
# Out:
# seed: 1452105090

# %%
result = BenchmarkRunner(algo=Brute_Force(.5)).run(
    max_houses=6, 
    max_time_steps=24, 
    house_interval=2, 
    time_step_interval=24,
    file_location="C:/Users/steve/OneDrive/Dokumente/Universität/BA/Messung"
)
result
# Out:
# finished house 2/6 in 0.006 seconds
# finished house 4/6 in 0.054 seconds
# finished house 6/6 in 0.981 seconds
# time_step_count        24
# house_count
# 2                0.006335
# 4                0.053919
# 6                0.981165

# %%
x = np.array([1,-2])/np.array([1,2]).max()
x
# Out:
# array([ 0.5, -1. ])
