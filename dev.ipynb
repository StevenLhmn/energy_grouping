# %%
from time import perf_counter
start = perf_counter()
from shapely.geometry import Point
print(f'imported Point in {perf_counter() - start:.3f} sec')
start = perf_counter()
import geopandas as gpd
print(f'imported gpd in {perf_counter() - start:.3f} sec')
start = perf_counter()
import pandas as pd
print(f'imported pd in {perf_counter() - start:.3f} sec')
start = perf_counter()
import numpy as np
print(f'imported np in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data_gen.region_generator import RegionGenerator
print(f'imported RegionGen in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data.measurment import Measurement
print(f'imported Measurement in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.brute_force import Brute_Force
print(f'imported BruteF in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.controller.benchmark_runner import BenchmarkRunner
print(f'imported Benchmark in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.animation.animation import Animation
print(f'imported Animation in {perf_counter() - start:.3f} sec')
start = perf_counter()
import plotly.graph_objects as go
print(f'imported Go in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.animation.trajectory import Trajectory
print(f'imported traj in {perf_counter() - start:.3f} sec')
start = perf_counter()
import plotly.express as px
print(f'imported px in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.utilities.seed_container import Seed_Container
print(f'imported SeedContainer in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.data.grouped_region import GroupedRegion
print(f'imported Grouped_Region in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.genetic import Genetic
print(f'imported Genetic in {perf_counter() - start:.3f} sec')
start = perf_counter()
from src.grouping.k_means import K_Means
print(f'imported K-Means in {perf_counter() - start:.3f} sec')
# Out:
# imported Point in 0.220 sec
# imported gpd in 0.653 sec
# imported pd in 0.000 sec
# imported np in 0.000 sec
# imported RegionGen in 0.261 sec
# imported Measurement in 0.018 sec
# imported BruteF in 0.749 sec
# imported Benchmark in 0.002 sec
# imported Animation in 0.001 sec
# imported Go in 0.000 sec
# imported traj in 0.000 sec
# imported px in 0.236 sec
# imported SeedContainer in 0.000 sec
# imported Grouped_Region in 0.000 sec
# imported Genetic in 0.002 sec
# imported K-Means in 2.107 sec

# %%
sc = Seed_Container(seed=None)
region = RegionGenerator(seed_container=sc).random(50, 1, 10)
algo = K_Means(sc, 1, 5, 10)
result = algo.group(region=region, animate=True)
animation = Animation().play(algo.get_trajectory())

# %% [markdown]
# warum nur alle 3 schritte änderung? warum bei distance weight 1 nicht gruppen bildung,

# %%
print(f'before: {result.get_autarky_without_groups():.3f}, after: {result.region_autarky():.3f}')

result.houses
# Out:
# before: 0.703, after: 0.914
#        coordinate load  gen                     id  label
# 0   POINT (43 98)  [4]  [4]  X43.000000|Y98.000000      2
# 1    POINT (37 6)  [6]  [9]   X37.000000|Y6.000000      1
# 2   POINT (17 73)  [2]  [5]  X17.000000|Y73.000000      2
# 3   POINT (97 38)  [8]  [5]  X97.000000|Y38.000000      4
# 4   POINT (45 34)  [8]  [6]  X45.000000|Y34.000000      0
# 5   POINT (19 21)  [3]  [5]  X19.000000|Y21.000000      1
# 6   POINT (68 69)  [8]  [1]  X68.000000|Y69.000000      3
# 7   POINT (66 23)  [8]  [8]  X66.000000|Y23.000000      4
# 8   POINT (51 34)  [2]  [6]  X51.000000|Y34.000000      0
# 9   POINT (13 17)  [2]  [5]  X13.000000|Y17.000000      1
# 10  POINT (35 17)  [4]  [2]  X35.000000|Y17.000000      1
# 11  POINT (60 40)  [5]  [9]  X60.000000|Y40.000000      0
# 12  POINT (22 59)  [1]  [8]  X22.000000|Y59.000000      2
# 13  POINT (84 74)  [3]  [8]  X84.000000|Y74.000000      3
# 14  POINT (20 74)  [2]  [3]  X20.000000|Y74.000000      2
# 15   POINT (92 5)  [8]  [3]   X92.000000|Y5.000000      4
# 16   POINT (6 29)  [5]  [6]   X6.000000|Y29.000000      1
# 17   POINT (3 12)  [6]  [9]   X3.000000|Y12.000000      1
# 18   POINT (8 60)  [4]  [9]   X8.000000|Y60.000000      2
# 19  POINT (49 43)  [2]  [7]  X49.000000|Y43.000000      0
# 20   POINT (7 98)  [8]  [3]   X7.000000|Y98.000000      2
# 21  POINT (28 43)  [7]  [6]  X28.000000|Y43.000000      0
# 22  POINT (48 53)  [9]  [3]  X48.000000|Y53.000000      0
# 23  POINT (73 49)  [7]  [8]  X73.000000|Y49.000000      3
# 24  POINT (51 18)  [6]  [8]  X51.000000|Y18.000000      0
# 25   POINT (4 99)  [5]  [6]   X4.000000|Y99.000000      2
# 26   POINT (3 97)  [3]  [1]   X3.000000|Y97.000000      2
# 27  POINT (41 81)  [9]  [7]  X41.000000|Y81.000000      2
# 28  POINT (39 59)  [8]  [9]  X39.000000|Y59.000000      0
# 29  POINT (14 39)  [1]  [7]  X14.000000|Y39.000000      1
# 30   POINT (84 9)  [6]  [9]   X84.000000|Y9.000000      4
# 31  POINT (85 31)  [7]  [2]  X85.000000|Y31.000000      4
# 32  POINT (22 61)  [2]  [4]  X22.000000|Y61.000000      2
# 33  POINT (90 34)  [7]  [1]  X90.000000|Y34.000000      4
# 34  POINT (12 75)  [9]  [3]  X12.000000|Y75.000000      2
# 35    POINT (4 7)  [8]  [4]    X4.000000|Y7.000000      1
# 36   POINT (17 1)  [4]  [7]   X17.000000|Y1.000000      1
# 37  POINT (49 36)  [7]  [2]  X49.000000|Y36.000000      0
# 38  POINT (63 32)  [6]  [4]  X63.000000|Y32.000000      0
# 39  POINT (14 87)  [3]  [9]  X14.000000|Y87.000000      2
# 40  POINT (37 28)  [7]  [7]  X37.000000|Y28.000000      0
# 41  POINT (58 26)  [5]  [8]  X58.000000|Y26.000000      0
# 42  POINT (12 32)  [1]  [9]  X12.000000|Y32.000000      1
# 43  POINT (94 28)  [9]  [3]  X94.000000|Y28.000000      4
# 44  POINT (20 54)  [7]  [5]  X20.000000|Y54.000000      2
# 45  POINT (25 78)  [6]  [1]  X25.000000|Y78.000000      2
# 46  POINT (96 34)  [5]  [5]  X96.000000|Y34.000000      4
# 47  POINT (29 11)  [6]  [6]  X29.000000|Y11.000000      1
# 48   POINT (39 9)  [9]  [5]   X39.000000|Y9.000000      1
# 49   POINT (21 1)  [1]  [6]   X21.000000|Y1.000000      1

# %%
print(f'seed: {sc.seed()}')
# Out:
# seed: 464829605

# %%
result = BenchmarkRunner(algo=Brute_Force(.5)).run(
    max_houses=6, 
    max_time_steps=24, 
    house_interval=2, 
    time_step_interval=24,
    file_location="C:/Users/steve/OneDrive/Dokumente/Universität/BA/Messung"
)
result
# Out:
# finished house 2/6 in 0.023 seconds
# finished house 4/6 in 0.103 seconds
# finished house 6/6 in 2.111 seconds
# time_step_count        24
# house_count
# 2                0.023400
# 4                0.103477
# 6                2.111329

# %%
x = np.array([1,-2])/np.array([1,2]).max()
x
# Out:
# array([ 0.5, -1. ])
