# %%
from src.data.region import Region
import geopandas as gpd
import numpy as np
from shapely import Point
gdf = gpd.GeoDataFrame(
        {
            'gen': [
                np.array([1, 2, 3]),
                np.array([4, 5, 6]),
                np.array([7, 8, 9])],
            'load': [
                np.array([1, 2, 3]),
                np.array([4, 5, 6]),
                np.array([7, 8, 9])],
            'coordinate': [
                Point(0, 0),
                Point(1.6516, 1.165),
                Point(2, 2)]
        }
    )
region = Region(houses=gdf)
ids = region.get_indexes()
ids
# Out:
# 0    X:0.000000|Y:0.000000
# 1    X:1.651600|Y:1.165000
# 2    X:2.000000|Y:2.000000
# Name: id, dtype: str
